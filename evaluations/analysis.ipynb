# %%
import pandas as pd
import numpy as np
import os
pd.set_option('display.width', 55)



#df of mape
df = pd.read_csv(r"C:\Users\Gillian  Zaragosa\Documents\PythonProjects\ml-for-forecasting\evaluations\mape.csv")
df
# Out:
#                                        fname  \
# 0                  time_series-AMZN-1day.csv
# 1                   time_series-TEL-1day.csv
# 2                  time_series-NFLX-1day.csv
# 3                   time_series-NKE-1day.csv
# 4                   time_series-TXN-1day.csv
# 5              time_series-AAPL-1day (3).csv
# 6                    time_series-GS-1day.csv
# 7           daylight_duration-2024-10-08.csv
# 8                   time_series-CRM-1day.csv
# 9                 time_series-RDS.A-1day.csv
# 10                  time_series-XOM-1day.csv
# 11                   time_series-PG-1day.csv
# 12                  time_series-PEP-1day.csv
# 13                  time_series-IBM-1day.csv
# 14                  time_series-TGT-1day.csv
# 15                 time_series-ABBV-1day.csv
# 16                  time_series-DIS-1day.csv
# 17                 time_series-NVDA-1day.csv
# 18                  time_series-UNH-1day.csv
# 19                  time_series-SMC-1day.csv
# ...

# %%
df.describe()
# Out:
#               ridge            rf   lr            gb           xbg  \
# count  5.000000e+01  5.000000e+01  0.0  5.000000e+01  5.000000e+01
# mean   2.499706e+14  2.672567e+14  NaN  2.000703e+14  1.472362e+14
# std    1.401506e+15  1.460842e+15  NaN  1.048232e+15  7.287116e+14
# min    1.120635e-04  5.175128e-03  NaN  8.438482e-04  9.090279e-04
# 25%    2.149919e-02  2.438257e-02  NaN  2.456429e-02  2.470212e-02
# 50%    2.877814e-02  3.560442e-02  NaN  3.467647e-02  3.221137e-02
# 75%    4.541774e-02  8.023313e-02  NaN  1.004556e-01  8.812295e-02
# max    9.509973e+15  9.752049e+15  NaN  6.705721e+15  3.734791e+15
#
#                  dt         lasso           enr           knn
# count  5.000000e+01  5.000000e+01  5.000000e+01  5.000000e+01
# mean   1.603279e+14  2.042963e+14  2.061278e+14  1.248246e+14
# std    7.999065e+14  1.084954e+15  1.090108e+15  6.995025e+14
# min    3.361463e-03  4.265757e-03  3.811828e-03  4.152103e-03
# ...
